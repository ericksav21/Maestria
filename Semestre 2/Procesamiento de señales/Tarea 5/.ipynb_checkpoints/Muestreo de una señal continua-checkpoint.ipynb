# %% [markdown]
# Alumno: Erick Salvador Alvarez Valencia

# %% [markdown]
# ## Demostrar que para una señal $g(n) = \sum_{k = 0}^{N - 1}C_k S_k(n)$ sólo hay $N$ señales distintas

# %% [markdown]
# Tenemos que $S_k(n) = e^{i \omega kn} = e^{i2 \pi k f_0 n}$
#
# Ahora, sabemos por definición que la siguiente propiedad se cumple:
#
# $$S_k(n + N) = e^{i2 \pi k f_0 (n + N)} = e^{i2 \pi k f_0 n} = S_k(n)$$
#
# De acuerdo a lo anterior, como el periodo es $N$ sólo hay $N$ exponenciales complejas.
#
# Ahora se demostrará que esto también se cumple con una combinación lineal de la señal anterior.
# Se tiene que: $g(n) = \sum_{k = 0}^{N - 1}C_k S_k(n)$
#
# Por lo que:
#
# $$g(n + N) = \sum_{k = 0}^{N - 1}C_k S_k(n + N)$$
# $$= \sum_{k = 0}^{N - 1}C_k e^{i2 \pi k f_0 (n + N)}$$
#
# Pero por la propiedad anterior:
#
# $$= \sum_{k = 0}^{N - 1}C_k e^{i2 \pi k f_0 n} = g(n)$$
#
# Con lo cual vemos que la periodicidad también aplica a la combinación lineal de las señales exponenciales.

# %%
import numpy as np
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib.cm as cm
from math import *

def derivative(t, a):
    return -2.0 * a * t * np.sin(a * t * t)

def get_domain(b0, b1, n):
    dt = fabs(b1 - b0) / (n - 1)
    t = np.zeros(n, dtype = 'float64')
    for i in range(n):
        t[i] = b0 + i * dt
    return t

def fs_max(b0, b1, a, n):
    dt = (b1 - b0) / (n - 1)
    t = get_domain(b0, b1, n)
    y = derivative(t, a)
    return max(y)

def create_graph(b0, b1, a):
    #Obtener la frecuencia de muestreo
    Fs = 2.0 * fs_max(b0, b1, a, 5000)
    T = 1.0 / Fs
    print("Periodo de muestreo: " + str(T))
    t = get_domain(b0, b1, int((b1 - b0) / T))
    y = np.cos(a * t * t)
    return t, y

a = 60.0
b0 = 10.0
b1 = 15.0
t, y = create_graph(b0, b1, a)

# %matplotlib inline
fig = plt.figure(figsize = (50, 20))
ax = fig.add_subplot(221)

ax.plot(t, y, 'k', color = "red")
ax.set_title("Muestro de la función $y = cos(at^2)$")
# Out:
# Periodo de muestreo: 0.000279578279596
# Text(0.5,1,'Muestro de la función $y = cos(at^2)$')

# %% [markdown]
# Como vemos la señal anterior no se puede apreciar bien después debido a la escala del plotter, por lo cual se mostrará la misma en un intervalo más pequeño (10, 10.5).

# %%
a = 60.0
b0 = 10.0
b1 = 10.1

#Obtener la frecuencia de muestreo
Fs = 2.0 * fs_max(b0, b1, a, 1000)
print("La mínima frecuencia de muestreo es: " + str(ceil(Fs)))
T = 1.0 / (Fs)
t = get_domain(b0, b1, int((b1 - b0) / T))
y = np.cos(a * t * t)

# %matplotlib inline
fig = plt.figure(figsize = (20, 4))
ax = fig.add_subplot(111)

ax.plot(t, y, 'k', t, y, 'ro')
ax.set_title("Muestro de la función $y = cos(at^2)$")
# Out:
# La mínima frecuencia de muestreo es: 2422
# Text(0.5,1,'Muestro de la función $y = cos(at^2)$')

# %% [markdown]
# Igualmente podemos hacer un zoom a la gráfica original con el método $\textit{axis}$ de pyplot.

# %%
a = 60.0
b0 = 10.0
b1 = 15.0
t, y = create_graph(b0, b1, a)

# %matplotlib inline
fig = plt.figure(figsize = (50, 20))
ax = fig.add_subplot(221)

ax.plot(t, y, 'k', color = "blue")
ax.set_title("Muestro de la función $y = cos(at^2)$")
ax.axis([11, 11.05, -1.0, 1.0])
# Out:
# Periodo de muestreo: 0.000279578279596
# [11, 11.05, -1.0, 1.0]

# %% [markdown]
# ## $s(x, b) = cos(a(x^2 + y^2))$

# %% [markdown]
# En esta parte se hará el muestreo de una señal la cual es función de 2 variables. Nota: El primer plot tarda un poco en generarse.

# %%
def f(x, y, a):
    return np.cos(a * (x * x + y * y))

def par_derivative_x(x, y, a):
    return -2.0 * a *  x * np.sin(a * (x * x + y * y))

def par_derivative_y(x, y, a):
    return -2.0 * a *  y * np.sin(a * (x * x + y * y))

def fs_max_xy(x0, x1, y0, y1, a, n):
    x = get_domain(x0, x1, n)
    y = get_domain(y0, y1, n)
    X, Y = np.meshgrid(x, y)
    zx = par_derivative_x(X, Y, a)
    zy = par_derivative_y(X, Y, a)
        
    return zx.max(), zy.max()

def create_graph_xy(x0, x1, y0, y1, a, plot_type, f_size = (10, 10)):
    #Obtener la frecuencia de muestreo
    Fs_x, Fs_y = fs_max_xy(x0, x1, y0, y1, a, 1000)
    Tx = 1.0 / (2.0 * Fs_x)
    Ty = 1.0 / (2.0 * Fs_y)
    print("Periodo de muestro para X: " + str(Tx) + ". Periodo de muestreo para Y: " + str(Ty))
    x = np.arange(x0, x1, Tx)
    y = np.arange(y0, y1, Ty)
    X, Y = np.meshgrid(x, y)
    Z = f(X, Y, a)
    
    fig = plt.figure(figsize = f_size)
    if plot_type == "contour":
        ax1 = fig.add_subplot(1, 2, 1)
        ax1.imshow(Z, cmap = cm.gray)
        ax1.set_title("Contorno de la función $f(x, y) = cos(a(x^2 + y^2))$")
    elif plot_type == "surface":
        ax2 = fig.add_subplot(1, 2, 1, projection = "3d")
        ax2.plot_wireframe(X, Y, Z, rcount = 100, ccount = 100)
        ax2.set_title("Superficie de la función $f(x, y) = cos(a(x^2 + y^2))$")
    else:
        print("No se pudo determinó el tipo de gráfica.")

a = 60.0
x0 = 10
x1 = 13
y0 = -10
y1 = -5


create_graph_xy(x0, x1, y0, y1, a, "contour")
# Out:
# Periodo de muestro para X: 0.000320512860237. Periodo de muestreo para Y: 0.000416666704386

# %% [markdown]
# Ahora se mostrará un plot de la superficie de la imagen.

# %%
a = 60.0
x0 = -0.2
x1 = 0.2
y0 = -0.2
y1 = 0.2

create_graph_xy(x0, x1, y0, y1, a, "surface", (20, 10))
# Out:
# Periodo de muestro para X: 0.0208333710838. Periodo de muestreo para Y: 0.0208333710838

# %% [markdown]
# ## $s(x, y) = \sum_{k = 0}^{18} a_k x^k + \sum_{j = 0}^{10} b_k y^k$

# %% [markdown]
# Ahora se hará lo mismo para el caso anterior, la diferencia es que se hará un polinomio con coeficientes generados por una distribución uniforme.

# %%
def f(x, y, a, b):
    res = 0.0
    x_pow = np.power(x, np.arange(0, 19))
    y_pow = np.power(y, np.arange(0, 12))
    for k in range(x_pow.size):
        res += a[k] * x_pow[k]
    for j in range(y_pow.size):
        res += b[j] * y_pow[j]
    return res

def par_derivative_x(x, a):
    res = a[1]
    for k in range(2, 19):
        res += (k * a[k] * np.power(x, k - 1))
    return res

def par_derivative_y(y, b):
    res = b[1]
    for j in range(2, 12):
        res += (j * b[j] * np.power(y, j - 1))
    return res

def fs_max_xy(x0, x1, y0, y1, ak, bj, n):
    x = get_domain(x0, x1, n)
    y = get_domain(y0, y1, n)
    max_x = -1.0
    max_y = -1.0
    
    for i in range(x.size):
        max_x = max(max_x, par_derivative_x(x[i], ak))
    
    for i in range(y.size):
        max_y = max(max_y, par_derivative_y(y[i], bj))
    return max_x, max_y

def create_graph_xy(x0, x1, y0, y1, ak, bj):
    #Obtener la frecuencia de muestreo
    Fs_x, Fs_y = fs_max_xy(x0, x1, y0, y1, ak, bj, 1000)
    Tx = 1.0 / (2.0 * Fs_x)
    Ty = 1.0 / (2.0 * Fs_y)
    print("Periodo de muestro para X: " + str(Tx) + ". Periodo de muestreo para Y: " + str(Ty))
    x = np.arange(x0, x1, Tx)
    y = np.arange(y0, y1, Ty)
    z = np.zeros((y.size, x.size), dtype = 'float')
    
    for i in range(y.size):
        for j in range(x.size):
            z[i][j] = f(x[j], y[i], ak, bj)

    fig = plt.figure(figsize = (10, 10))
    ax = fig.add_subplot(1, 2, 1)
    ax.imshow(z, cmap = cm.gray)
    ax.set_title("Contorno de la función $s(x, y) = \sum_{k = 0}^{18} a_k x^k + \sum_{j = 0}^{10} b_k y^k$")
        
ak = np.random.uniform(0, 7, 19)
bj = np.random.uniform(0, 7, 12)

x0 = -0.5
x1 = 0.7
y0 = -0.5
y1 = 0.7
create_graph_xy(x0, x1, y0, y1, ak, bj)
# Out:
# Periodo de muestro para X: 0.0119625161629. Periodo de muestreo para Y: 0.0156343916618
